# %% [markdown]
# ![image.png](attachment:image.png)

# %%
M     = 2   # kg
K     = 10  # N/m
C     = 1.5 # kg/s
G_s   = 20  # N
T_max = 10  # s

# %% [markdown]
# Equation a resoudre:
# $$
# \frac{d^2 x}{d t^2} + \frac{c}{m}\frac{dx}{dt}+\frac{k}{m}x = \frac{g_s}{m}
# $$
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)
